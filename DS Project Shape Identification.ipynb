# %% [markdown]
# # Import libraries

# %%
! pip install tensorflow
! pip install opencv-python
! pip install pandas
! pip install numpy 
! pip install matplotlib
! pip install pickle-mixin
# Out:
# Requirement already satisfied: tensorflow in c:\users\samar\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: packaging in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (22.0)
# Requirement already satisfied: setuptools in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (65.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.23.5)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.4.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\samar\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\samar\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\samar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\samar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\samar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\samar\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\samar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\samar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\samar\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\samar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\samar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Requirement already satisfied: opencv-python in c:\users\samar\anaconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\samar\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: pandas in c:\users\samar\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\samar\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samar\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\samar\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\samar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\samar\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\samar\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samar\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\samar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pickle-mixin in c:\users\samar\anaconda3\lib\site-packages (1.0.2)

# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from random import shuffle
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical


import cv2

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading data

# %%
import os

BASE_DIR = 'C:\\Users\\samar\\Downloads\\archive (2)\\shapes'
shapes = os.listdir(BASE_DIR)
shapes
# Out:
# ['circle', 'square', 'star', 'triangle']

# %%
data = []
target = []
for i, shape in enumerate(shapes):
    path = os.path.join(BASE_DIR, shape)
    for filename in os.listdir(path):
        image = cv2.imread(os.path.join(path , filename),0)
        image = image.reshape(200,200,1)
        data.append(image)
        target.append(i)

# %% [markdown]
# # Preprocessing

# %%
data = np.array(data)
target = np.array(target)
target = to_categorical(target)

# %%
data.shape, target.shape
# Out:
# ((14970, 200, 200, 1), (14970, 4))

# %%
X_full, X_test, y_full, y_test = train_test_split(data, target, stratify=target, random_state= 42, test_size = 0.25)
X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, stratify=y_full, random_state= 42, test_size = 0.15)

# %% [markdown]
# Let's check some images to see if everything is alright

# %%
def show_images(count, X, y):
    fig, axes =plt.subplots(count//4,4, figsize = (16, count))
    for i, ind in enumerate(np.random.randint(0, X.shape[0] , count)):
        ax = axes[i//4][i%4] 
        ax.imshow(X[ind],cmap = 'gray')
        ax.title.set_text(shapes[np.argmax(y[ind])])
        ax.set_xticks([]) 
        ax.set_yticks([])
show_images(8, X_train, y_train)

# %%
show_images(8, X_val, y_val)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=180,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale = 1.0/255,
    horizontal_flip=True,
    vertical_flip=True)

val_datagen = ImageDataGenerator(rescale = 1.0/255)

# %%
X_test = X_test/255.0
X_train = X_train/255.0
X_val = X_val/255.0

# %% [markdown]
# # Modelling

# %%
model = Sequential([
    Conv2D(32, (3,3),strides = 2 ,input_shape = (200,200,1), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation = 'relu'),
    Dropout(0.5),
    Dense(64, activation = 'relu'),
    Dropout(0.5),
    Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 99, 99, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 102244 (399.39 KB)
# Trainable params: 102244 (399.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

history = model.fit(X_train, y_train, epochs = 5, validation_data = (X_val, y_val))
# Out:
# Epoch 1/5
# 299/299 [==============================] - 87s 274ms/step - loss: 0.4408 - accuracy: 0.7930 - val_loss: 0.0023 - val_accuracy: 0.9994
# Epoch 2/5
# 299/299 [==============================] - 78s 263ms/step - loss: 0.0352 - accuracy: 0.9892 - val_loss: 0.0010 - val_accuracy: 0.9994
# Epoch 3/5
# 299/299 [==============================] - 79s 264ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 2.7992e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 299/299 [==============================] - 78s 261ms/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 1.2663e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 299/299 [==============================] - 78s 262ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 6.9390e-05 - val_accuracy: 1.0000

# %%
metrics = pd.DataFrame(history.history)
plt.plot(metrics)
# Out:
# [<matplotlib.lines.Line2D at 0x1d6f90f4eb0>,
#  <matplotlib.lines.Line2D at 0x1d6f90f4f10>,
#  <matplotlib.lines.Line2D at 0x1d6f90f4f40>,
#  <matplotlib.lines.Line2D at 0x1d6f90f5030>]

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy is {}%'.format(accuracy*100))
# Out:
# 117/117 [==============================] - 9s 79ms/step - loss: 1.0172e-04 - accuracy: 1.0000
# Accuracy is 100.0%

# %%
def show_images_predicted(count, X, y):
    fig, axes =plt.subplots(count//4,4, figsize = (16, count))
    for i, ind in enumerate(np.random.randint(0, X.shape[0] , count)):
        ax = axes[i//4][i%4] 
        ax.imshow(X[ind],cmap = 'gray')
        res=""
        if y[ind][0]==1:
            res+="circle"
        if y[ind][1]==1:
            res+="square"
        if y[ind][2]==1:
            res="star"
        if y[ind][3]==1:
            res="triangle"
        ax.title.set_text(res)
        ax.set_xticks([]) 
        ax.set_yticks([])

# %%
preds = model.predict(X_test)
show_images_predicted(16,X_test, preds)
# Out:
# 117/117 [==============================] - 10s 77ms/step

# %%
# Out:
# Requirement already satisfied: pickle-mixin in c:\users\samar\anaconda3\lib\site-packages (1.0.2)

# %%
BASE_DIR = r'C:\Users\samar\Downloads\archive (2)\shapes\star'

shapes = os.listdir(BASE_DIR)

data = []

count=12
for filename in shapes:
    image_path = os.path.join(BASE_DIR, filename)
    image = cv2.imread(image_path, 0) 
    image = image.reshape(200, 200, 1)
    data.append(image)

data = np.array(data)
print(data.shape)
data = data/255.0

preds = model.predict(data)

show_images_predicted(count, data, preds)
# Out:
# (3765, 200, 200, 1)
# 118/118 [==============================] - 9s 78ms/step

# %%
import cv2
import time
import numpy as np

# Define an empty list to store image data
data1 = []

# Function to make predictions with the model
def predict_with_model(image_data):
    image_data = np.array(image_data)
    y = model.predict(image_data)
    res=""
    if y[-1][0]==1:
        res+="circle"
    if y[-1][1]==1:
        res+="square"
    if y[-1][2]==1:
        res="star"
    if y[-1][3]==1:
        res="triangle"
    cv2.putText(img_gray, res, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Open the camera capture
cap = cv2.VideoCapture(0)

# Set the desired frame width and height
frame_width = 200
frame_height = 200
cap.set(3, frame_width)  # 3 corresponds to frame width
cap.set(4, frame_height)  # 4 corresponds to frame height

while True:
    success, img = cap.read()
    
    # Ensure the captured frame is not None
    if img is not None:
        # Convert the image to grayscale
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Resize the image to 200x200 pixels
        img_gray = cv2.resize(img_gray, (frame_width, frame_height))
        
        # Expand the dimensions to match the desired shape (1, 200, 200, 1)
        img_gray = np.expand_dims(img_gray, axis=-1)
        
        # Append the image to the data1 list
        data1.append(img_gray)
    
        if len(data1) > 0:
            preds = predict_with_model(data1)
            print(preds)
        
        # Display the image
        cv2.imshow("Image", img_gray[:, :, 0])
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # Press 'q' to exit the loop
        break

# Release the camera
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 333ms/step
# None
# 1/1 [==============================] - 0s 32ms/step
# None
# 1/1 [==============================] - 0s 31ms/step
# None
# 1/1 [==============================] - 0s 41ms/step
# None
# 1/1 [==============================] - 0s 31ms/step
# None
# 1/1 [==============================] - 0s 39ms/step
# None
# 1/1 [==============================] - 0s 33ms/step
# None
# 1/1 [==============================] - 0s 33ms/step
# None
# 1/1 [==============================] - 0s 39ms/step
# None
# 1/1 [==============================] - 0s 39ms/step
# None
# 1/1 [==============================] - 0s 41ms/step
# None
# 1/1 [==============================] - 0s 50ms/step
# None
# 1/1 [==============================] - 0s 49ms/step
# None
# 1/1 [==============================] - 0s 55ms/step
# None
# 1/1 [==============================] - 0s 42ms/step
# None
# 1/1 [==============================] - 0s 33ms/step
# None
# 1/1 [==============================] - 0s 56ms/step
# None
# 1/1 [==============================] - 0s 55ms/step
# None
# 1/1 [==============================] - 0s 57ms/step
# None
# 1/1 [==============================] - 0s 49ms/step
# None
# 1/1 [==============================] - 0s 56ms/step
# None
# 1/1 [==============================] - 0s 54ms/step
# None
# 1/1 [==============================] - 0s 50ms/step
# None
# 1/1 [==============================] - 0s 54ms/step
# None
# 1/1 [==============================] - 0s 72ms/step
# None
# 1/1 [==============================] - 0s 64ms/step
# None
# 1/1 [==============================] - 0s 63ms/step
# None
# 1/1 [==============================] - 0s 53ms/step
# None
# 1/1 [==============================] - 0s 58ms/step
# None
# 1/1 [==============================] - 0s 65ms/step
# None
# 1/1 [==============================] - 0s 66ms/step
# None
# 1/1 [==============================] - 0s 66ms/step
# None
# 2/2 [==============================] - 0s 8ms/step
# None
# 2/2 [==============================] - 0s 8ms/step
# None
# 2/2 [==============================] - 0s 9ms/step
# None
# 2/2 [==============================] - 0s 16ms/step
# None
# 2/2 [==============================] - 0s 16ms/step
# None
# 2/2 [==============================] - 0s 26ms/step
# None
# 2/2 [==============================] - 0s 19ms/step
# None
# 2/2 [==============================] - 0s 22ms/step
# None
# 2/2 [==============================] - 0s 22ms/step
# None
# 2/2 [==============================] - 0s 18ms/step
# None
# 2/2 [==============================] - 0s 16ms/step
# None
# 2/2 [==============================] - 0s 26ms/step
# None
# 2/2 [==============================] - 0s 34ms/step
# None
# 2/2 [==============================] - 0s 26ms/step
# None
# 2/2 [==============================] - 0s 27ms/step
# None
# 2/2 [==============================] - 0s 25ms/step
# None
# 2/2 [==============================] - 0s 27ms/step
# None
# 2/2 [==============================] - 0s 25ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 26ms/step
# None
# 2/2 [==============================] - 0s 27ms/step
# None
# 2/2 [==============================] - 0s 26ms/step
# None
# 2/2 [==============================] - 0s 31ms/step
# None
# 2/2 [==============================] - 0s 33ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 36ms/step
# None
# 2/2 [==============================] - 0s 45ms/step
# None
# 2/2 [==============================] - 0s 35ms/step
# None
# 2/2 [==============================] - 0s 36ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 34ms/step
# None
# 2/2 [==============================] - 0s 35ms/step
# None
ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 31ms/step
# None
# 8/8 [==============================] - 0s 31ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 31ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 31ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 32ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 36ms/step
# None
# 8/8 [==============================] - 0s 33ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 36ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 35ms/step
# None
# 8/8 [==============================] - 0s 35ms/step
# None
# 8/8 [==============================] - 0s 35ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 35ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 8/8 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 30ms/step
# None
# 9/9 [==============================] - 0s 33ms/step
# None
# 9/9 [==============================] - 0s 36ms/step
# None
# 9/9 [==============================] - 0s 31ms/step
# None
# 9/9 [==============================] - 0s 32ms/step
# None
# 9/9 [==============================] - 0s 32ms/step
# None
# 9/9 [==============================] - 0s 31ms/step
# None
# 9/9 [==============================] - 0s 31ms/step
# None
# 9/9 [==============================] - 0s 32ms/step
# None
# 9/9 [==============================] - 0s 32ms/step
# None
# 9/9 [==============================] - 0s 33ms/step
# None
# 9/9 [==============================] - 0s 33ms/step
# None
# 9/9 [==============================] - 0s 33ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 33ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 36ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 35ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 35ms/step
# None
# 9/9 [==============================] - 0s 32ms/step
# None
# 9/9 [==============================] - 0s 35ms/step
# None
# 9/9 [==============================] - 0s 36ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 9/9 [==============================] - 0s 35ms/step
# None
# 9/9 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 31ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 31ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 32ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 35ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 36ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 10/10 [==============================] - 0s 35ms/step
# None
# 10/10 [==============================] - 0s 36ms/step
# None
# 10/10 [==============================] - 0s 33ms/step
# None
# 10/10 [==============================] - 0s 36ms/step
# None
# 10/10 [==============================] - 0s 36ms/step
# None
# 10/10 [==============================] - 0s 36ms/step
# None
# 10/10 [==============================] - 0s 35ms/step
# None
# 10/10 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 30ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 32ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 33ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 34ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 11/11 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 32ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 34ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 33ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 37ms/step
# None
# 12/12 [==============================] - 0s 36ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 36ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 35ms/step
# None
# 12/12 [==============================] - 0s 36ms/step
# None
# 12/12 [==============================] - 0s 37ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 36ms/step
# None
# 13/13 [==============================] - 1s 40ms/step
# None
# 13/13 [==============================] - 1s 37ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 33ms/step
# None
# 13/13 [==============================] - 0s 36ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 13/13 [==============================] - 0s 36ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 1s 38ms/step
# None
# 13/13 [==============================] - 0s 36ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 1s 36ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 35ms/step
# None
# 13/13 [==============================] - 0s 36ms/step
# None
# 13/13 [==============================] - 0s 34ms/step
# None
# 14/14 [==============================] - 0s 32ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 0s 32ms/step
# None
# 14/14 [==============================] - 0s 32ms/step
# None
# 14/14 [==============================] - 0s 31ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 1s 34ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 1s 34ms/step
# None
# 14/14 [==============================] - 0s 31ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 0s 33ms/step
# None
# 14/14 [==============================] - 1s 34ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 1s 37ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 1s 36ms/step
# None
# 14/14 [==============================] - 1s 38ms/step
# None
# 14/14 [==============================] - 1s 37ms/step
# None
# 14/14 [==============================] - 1s 38ms/step
# None
# 14/14 [==============================] - 1s 39ms/step
# None
# 14/14 [==============================] - 1s 37ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 14/14 [==============================] - 1s 38ms/step
# None
# 14/14 [==============================] - 1s 36ms/step
# None
# 14/14 [==============================] - 1s 36ms/step
# None
# 14/14 [==============================] - 1s 35ms/step
# None
# 15/15 [==============================] - 0s 29ms/step
# None
# 15/15 [==============================] - 0s 27ms/step
# None
# 15/15 [==============================] - 0s 29ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 15/15 [==============================] - 1s 38ms/step
# None
# 15/15 [==============================] - 1s 37ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 15/15 [==============================] - 1s 37ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 37ms/step
# None
# 15/15 [==============================] - 1s 47ms/step
# None
# 15/15 [==============================] - 1s 68ms/step
# None
# 15/15 [==============================] - 1s 47ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 35ms/step
# None
# 15/15 [==============================] - 1s 33ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 15/15 [==============================] - 1s 35ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 35ms/step
# None
# 15/15 [==============================] - 1s 35ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 34ms/step
# None
# 15/15 [==============================] - 1s 36ms/step
# None
# 16/16 [==============================] - 1s 34ms/step
# None
# 16/16 [==============================] - 1s 33ms/step
# None
# 16/16 [==============================] - 1s 36ms/step
# None
# 16/16 [==============================] - 1s 35ms/step
# None
# 16/16 [==============================] - 1s 35ms/step
# None
# 16/16 [==============================] - 1s 35ms/step
# None
# 16/16 [==============================] - 1s 36ms/step
# None
# 16/16 [==============================] - 1s 34ms/step
# None
# 16/16 [==============================] - 1s 38ms/step
# None
# 16/16 [==============================] - 1s 34ms/step
# None
# 16/16 [==============================] - 1s 33ms/step
# None
# 16/16 [==============================] - 1s 36ms/step
# None
# 16/16 [==============================] - 1s 36ms/step
# None
# 16/16 [==============================] - 1s 35ms/step
# None
# 16/16 [==============================] - 1s 37ms/step
# None
# 16/16 [==============================] - 1s 41ms/step
# None
# 16/16 [==============================] - 1s 73ms/step
# None
# 16/16 [==============================] - 1s 73ms/step
# None
#  3/16 [====>.........................] - ETA: 0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 50
#      47 data1.append(img_gray)
#      49 if len(data1) > 0:
# ---> 50     preds = predict_with_model(data1)
#      51     print(preds)
#      53 # Display the image
#
# Cell In[20], line 11, in predict_with_model(image_data)
#       9 def predict_with_model(image_data):
#      10     image_data = np.array(image_data)
# ---> 11     y = model.predict(image_data)
#      12     res=""
#      13     if y[-1][0]==1:
#
# File ~\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\src\engine\training.py:2631, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2629 for step in data_handler.steps():
#    2630     callbacks.on_predict_batch_begin(step)
# -> 2631     tmp_batch_outputs = self.predict_function(iterator)
#    2632     if data_handler.should_sync:
#    2633         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:876, in Function._call(self, *args, **kwds)
#     873 self._lock.release()
#     874 # In this case we have not created variables on the first call. So we can
#     875 # run the first trace but we should fail if variables are created.
# --> 876 results = tracing_compilation.call_function(
#     877     args, kwds, self._variable_creation_config
#     878 )
#     879 if self._created_variables:
#     880   raise ValueError("Creating variables on a non-first call to a function"
#     881                    " decorated with tf.function.")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:
